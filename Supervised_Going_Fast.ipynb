# %% [markdown]
# # Homework - EDA

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.set(rc={'figure.figsize':(20.7,8.27)})
sns.set_style("whitegrid")
sns.color_palette("dark")
plt.style.use("fivethirtyeight")

# %% [markdown]
# # Load, Info, Missing and Describe Data

# %% [markdown]
# ## Load Data

# %%
data_product = pd.read_csv('D:\Dataset\Final_project\dataset.csv')

display(data_product)
# Out:
#        Administrative  Administrative_Duration  Informational  \
# 0                 0.0                 0.000000              0
# 1                 0.0                 0.000000              0
# 2                 0.0                 0.000000              0
# 3                 0.0                      NaN              0
# 4                 0.0                 0.000000              0
# ...               ...                      ...            ...
# 12941             0.0                 0.000000              0
# 12942             0.0                 0.000000              0
# 12943            14.0               484.461579              2
# 12944             3.0                60.833333              0
# 12945             0.0                 0.000000              0
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# 0                         0.0               1                 0.000000
# 1                         0.0               2                64.000000
# 2                         0.0               1                 0.000000
# 3                         0.0               2                 2.666667
# 4                         0.0              10               627.500000
# ...                       ...             ...                      ...
# 12941                     0.0               2                 0.000000
# 12942                     0.0              59              1309.658333
# 12943                    14.0              33               898.491579
# 12944                     0.0              18               884.633333
# 12945                     0.0               6               241.000000
#
#        BounceRates  ExitRates  PageValues  SpecialDay Month  OperatingSystems  \
# 0         0.200000   0.200000         0.0         0.0   Feb               1.0
# 1         0.000000   0.100000         0.0         0.0   Feb               2.0
# 2         0.200000   0.200000         0.0         0.0   Feb               4.0
# 3         0.050000   0.140000         0.0         0.0   Feb               3.0
# 4         0.020000   0.050000         0.0         0.0   Feb               3.0
# ...            ...        ...         ...         ...   ...               ...
# 12941     0.200000   0.200000         0.0         0.0   Nov               3.0
# 12942     0.017241   0.030879         0.0         0.0   Dec               3.0
# 12943     0.004269   0.034661         0.0         0.0   Sep               1.0
# 12944     0.021053   0.041140         0.0         0.0   Mar               2.0
# 12945     0.000000   0.033333         0.0         0.0   May               2.0
#
#        Browser  Region  TrafficType        VisitorType  Weekend  Revenue
# 0            1       1            1  Returning_Visitor    False    False
# 1            2       1            2  Returning_Visitor    False    False
# 2            1       9            3  Returning_Visitor    False    False
# 3            2       2            4  Returning_Visitor    False    False
# 4            3       1            4  Returning_Visitor     True    False
# ...        ...     ...          ...                ...      ...      ...
# 12941        2       1           13  Returning_Visitor    False    False
# 12942        2       3            1  Returning_Visitor    False    False
# 12943        8       1            3  Returning_Visitor    False    False
# 12944        2       3           10  Returning_Visitor    False    False
# 12945       10       2            3  Returning_Visitor    False    False
#
# [12946 rows x 18 columns]

# %%
data_product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12946 entries, 0 to 12945
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Administrative           12835 non-null  float64
#  1   Administrative_Duration  12313 non-null  float64
#  2   Informational            12946 non-null  int64
#  3   Informational_Duration   12946 non-null  float64
#  4   ProductRelated           12946 non-null  int64
#  5   ProductRelated_Duration  12307 non-null  float64
#  6   BounceRates              12872 non-null  float64
#  7   ExitRates                12946 non-null  float64
#  8   PageValues               12946 non-null  float64
#  9   SpecialDay               12946 non-null  float64
#  10  Month                    12946 non-null  object
#  11  OperatingSystems         12422 non-null  float64
#  12  Browser                  12946 non-null  int64
#  13  Region                   12946 non-null  int64
#  14  TrafficType              12946 non-null  int64
#  15  VisitorType              12946 non-null  object
#  16  Weekend                  12946 non-null  bool
#  17  Revenue                  12946 non-null  bool
# dtypes: bool(2), float64(9), int64(5), object(2)
# memory usage: 1.6+ MB

# %%
for col in data_product:
    print(col)
# Out:
# Administrative
# Administrative_Duration
# Informational
# Informational_Duration
# ProductRelated
# ProductRelated_Duration
# BounceRates
# ExitRates
# PageValues
# SpecialDay
# Month
# OperatingSystems
# Browser
# Region
# TrafficType
# VisitorType
# Weekend
# Revenue

# %% [markdown]
# ## Info Data
# Dataset ini memiliki 12,946 entri dengan 18 kolom. Di antara kolom-kolom tersebut, terdapat:
#
# 1. Administrative:
#
# Kolom ini berisi jumlah kunjungan administratif oleh pengguna situs web. Terdapat 12,835 entri non-null dalam kolom ini, yang berarti beberapa nilai mungkin kosong (null).
#
# 2. Administrative_Duration:
#
# Menunjukkan durasi kunjungan administratif oleh pengguna situs web dalam hitungan detik. Ada 12,313 entri non-null untuk kolom ini.
#
# 3. Informational:
#
# Merupakan jumlah kunjungan informatif oleh pengguna situs web. Semua 12,946 entri memiliki nilai non-null dalam kolom ini.
#
# 4. Informational_Duration:
#
# Kolom ini mencatat durasi kunjungan informatif oleh pengguna dalam hitungan detik. Semua 12,946 entri memiliki nilai non-null untuk kolom ini.
#
# 5. ProductRelated:
#
# Menunjukkan jumlah kunjungan terkait produk oleh pengguna situs web. Semua 12,946 entri memiliki nilai non-null dalam kolom ini.
#
# 6. ProductRelated_Duration:
#
# Durasi kunjungan terkait produk oleh pengguna dalam hitungan detik. Ada 12,307 entri non-null untuk kolom ini.
#
# 7. BounceRates:
#
# Tingkat bounce dalam kunjungan pengguna ke situs web. Ada 12,872 entri non-null untuk kolom ini.
#
# 8. ExitRates:
#
# Tingkat keluar dalam kunjungan pengguna ke situs web. Semua 12,946 entri memiliki nilai non-null untuk kolom ini.
#
# 9. PageValues:
#
# Nilai halaman yang terkait dengan kunjungan pengguna. Semua 12,946 entri memiliki nilai non-null untuk kolom ini.
#
# 10. SpecialDay:
#
# Indikator untuk menunjukkan dekatnya hari khusus seperti hari libur atau promosi khusus. Semua 12,946 entri memiliki nilai non-null untuk kolom ini.
#
# 11. Month:
#
# Menunjukkan bulan kunjungan pengguna. Semua 12,946 entri memiliki nilai non-null untuk kolom ini.
#
# 12. OperatingSystems:
#
# Merupakan sistem operasi yang digunakan oleh pengguna situs web. Ada 12,422 entri non-null untuk kolom ini.
#
# 13. Browser:
#
# Menunjukkan browser yang digunakan oleh pengguna situs web. Semua 12,946 entri memiliki nilai non-null untuk kolom ini.
#
# 14. Region:
#
# Wilayah geografis pengguna situs web. Semua 12,946 entri memiliki nilai non-null untuk kolom ini.
#
# 15. TrafficType:
#
# Tipe lalu lintas yang membawa pengguna ke situs web. Semua 12,946 entri memiliki nilai non-null untuk kolom ini.
#
# 16. VisitorType:
#
# Tipe pengunjung situs web (mungkin berupa 'Returning_Visitor', 'New_Visitor', atau 'Other'). Semua 12,946 entri memiliki nilai non-null untuk kolom ini.
#
# 17. Weekend:
#
# Kolom boolean yang menunjukkan apakah kunjungan dilakukan pada akhir pekan atau tidak.
#
# 18. Revenue:
#
# Kolom boolean yang menunjukkan apakah kunjungan menghasilkan pendapatan atau tidak.

# %%
import pandas as pd

# Misalkan data_product adalah DataFrame Anda
# Gantilah 'data_product' dengan nama DataFrame yang sesuai
unique_month = data_product['Month'].unique()
unique_visitor_type = data_product['VisitorType'].unique()
unique_weekend = data_product['Weekend'].unique()
unique_revenue = data_product['Revenue'].unique()

# Menampilkan nilai unik untuk setiap fitur
print("Nilai unik di Month:", unique_month)
print("Nilai unik di VisitorType:", unique_visitor_type)
print("Nilai unik di Weekend:", unique_weekend)
print("Nilai unik di Revenue:", unique_revenue)
# Out:
# Nilai unik di Month: ['Feb' 'Mar' 'May' 'Oct' 'June' 'Jul' 'Aug' 'Nov' 'Sep' 'Dec']
# Nilai unik di VisitorType: ['Returning_Visitor' 'New_Visitor' 'Other']
# Nilai unik di Weekend: [False  True]
# Nilai unik di Revenue: [False  True]

# %%
cats = ['Month', 'VisitorType', 'Weekend']
nums = ['Administrative', 'Administrative_Duration', 'Informational', 'Informational_Duration', 'ProductRelated', 'ProductRelated_Duration',
        'BounceRates', 'ExitRates', 'PageValues', 'SpecialDay', 'OperatingSystems', 'Browser', 'Region', 'TrafficType', ]

# %% [markdown]
# ## Grouping Feature
#
# Pemisahan kolom-kolom menjadi dua kategori, yaitu kategori kategorikal (cats) dan numerik (nums), biasanya dilakukan untuk mempermudah proses analisis data. Inilah alasan di balik pemisahan tersebut:
#
# 1. Kolom Kategorikal (cats):
#
# - Kolom-kolom ini berisi data yang mewakili kategori atau jenis tertentu, seperti bulan (Month), tipe pengunjung (VisitorType), atau apakah kunjungan dilakukan pada akhir pekan (Weekend).
# - Data dalam kolom ini memiliki nilai-nilai diskrit yang mewakili kategori tertentu, seperti 'Feb', 'Mar', 'May' untuk bulan, atau 'Returning_Visitor', 'New_Visitor', 'Other' untuk tipe pengunjung.
# - Saat melakukan analisis, seringkali kita ingin memahami pola dan hubungan antar kategori-kategori ini, seperti apakah ada perbedaan perilaku antara pengunjung yang kembali dan pengunjung baru, atau apakah ada pola kunjungan yang berkaitan dengan bulan tertentu.
#
# 2. Kolom Numerik (nums):
#
# - Kolom-kolom ini berisi data yang berupa angka atau nilai numerik, seperti jumlah kunjungan administratif (Administrative), durasi kunjungan administratif (Administrative_Duration), atau tingkat keluar (ExitRates).
# - Data dalam kolom ini biasanya bersifat kontinu atau berkelanjutan, yang dapat memiliki berbagai nilai dalam rentang tertentu.
# - Analisis pada kolom-kolom numerik ini seringkali melibatkan perhitungan statistik deskriptif, seperti rata-rata, median, atau deviasi standar, serta pembuatan visualisasi seperti histogram atau scatter plot untuk memahami distribusi dan hubungan antar variabel numerik.

# %%
data_product.describe().T
# Out:
#                            count         mean          std  min         25%  \
# Administrative           12835.0     2.303857     3.314427  0.0    0.000000
# Administrative_Duration  12313.0    80.370267   175.494016  0.0    0.000000
# Informational            12946.0     0.498841     1.263276  0.0    0.000000
# Informational_Duration   12946.0    34.136048   140.022848  0.0    0.000000
# ProductRelated           12946.0    31.657655    44.202635  0.0    7.000000
# ProductRelated_Duration  12307.0  1192.740077  1910.216261  0.0  182.083333
# BounceRates              12872.0     0.022309     0.048681  0.0    0.000000
# ExitRates                12946.0     0.043266     0.048808  0.0    0.014286
# PageValues               12946.0     5.875963    18.414670  0.0    0.000000
# SpecialDay               12946.0     0.061270     0.198667  0.0    0.000000
# OperatingSystems         12422.0     2.123169     0.906264  1.0    2.000000
# Browser                  12946.0     2.360497     1.718878  1.0    2.000000
# Region                   12946.0     3.144369     2.402477  1.0    1.000000
# TrafficType              12946.0     4.078248     4.025467  1.0    2.000000
#
#                                 50%          75%           max
# Administrative             1.000000     4.000000     27.000000
# Administrative_Duration    7.000000    92.933333   3398.750000
# Informational              0.000000     0.000000     24.000000
# Informational_Duration     0.000000     0.000000   2549.375000
# ProductRelated            18.000000    38.000000    705.000000
# ProductRelated_Duration  599.583333  1470.522917  63973.522230
# BounceRates                0.003112     0.016933      0.200000
# ExitRates                  0.025329     0.050000      0.200000
# PageValues                 0.000000     0.000000    361.763742
# SpecialDay                 0.000000     0.000000      1.000000
# OperatingSystems           2.000000     3.000000      8.000000
# Browser                    2.000000     2.000000     13.000000
# Region                     3.000000     4.000000      9.000000
# TrafficType                2.000000     4.000000     20.000000

# %% [markdown]
# ## Describe Data
#
# 1. Administrative_Duration:
#
# Nilai maksimum dari kolom durasi kunjungan administratif (Administrative_Duration) adalah 3398.75, sementara rata-rata (mean) hanya sekitar 80.37. Selisih antara nilai maksimum dan rata-rata yang sangat besar ini menunjukkan kemungkinan adanya outlier yang signifikan dalam data.
#
# 2. Informational_Duration:
#
# Sama seperti kolom sebelumnya, nilai maksimum dari durasi kunjungan informatif (Informational_Duration) adalah 2549.375, sementara rata-ratanya hanya sekitar 34.14. Ini juga menunjukkan kemungkinan adanya outlier dalam data.
#
# 3. ProductRelated:
#
# Nilai maksimum dari jumlah kunjungan terkait produk (ProductRelated) adalah 705, sementara rata-rata hanya sekitar 31.66. Sekali lagi, perbedaan yang signifikan antara nilai maksimum dan rata-rata menunjukkan kemungkinan adanya outlier dalam data.
#
# 4. ProductRelated_Duration:
#
# Nilai maksimum dari durasi kunjungan terkait produk (ProductRelated_Duration) adalah 63973.522230, sementara rata-ratanya hanya sekitar 1192.74. Hal ini menunjukkan kemungkinan adanya outlier dalam data.
#
# 5. PageValues:
#
# Nilai maksimum dari nilai halaman (PageValues) adalah 361.763742, yang jauh lebih tinggi dari rata-rata sekitar 5.88. Ini juga menunjukkan kemungkinan adanya outlier dalam data.

# %% [markdown]
# # Univarite Analysis

# %%
data_product2 = data_product.copy()

# %% [markdown]
# ## Violin Plot

# %%
import math
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))

for i in range(0, len(nums)):
    plt.subplot(math.ceil(len(nums) / 3), 3, i + 1)
    sns.violinplot(data=data_product2, y=data_product2[nums[i]], x='Revenue', linewidth=2, orient='v')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insight Violin Plot
#
#
# Violin plot adalah salah satu jenis visualisasi yang memungkinkan kita untuk melihat distribusi dari sebuah fitur atau variabel. Ketika melihat violin plot untuk fitur 'Administrative_Duration', 'Informational', 'Informational_Duration', 'ProductRelated', 'ProductRelated_Duration', dan 'PageValues', kita melihat adanya beberapa titik di ujung-ujung plot yang berada jauh dari area utama plot atau gambaran utama distribusinya. Titik-titik ini menunjukkan adanya outlier.

# %% [markdown]
# ## Box Plot

# %%
for i in range (0,len(nums)):
    plt.subplot(1, len (nums), i +1)
    sns.boxplot(y=data_product2[nums[i]], color = 'blue', orient='v')
    plt.tight_layout()

# %% [markdown]
# ## Insight Box Plot
#
# semua fitur box plot hanya menumpuk di bagian bawah, ini menunjukkan bahwa mayoritas data cenderung memiliki nilai yang rendah. Dalam konteks box plot, ini biasanya terlihat sebagai:
#
# 1. Median yang rendah: Garis tengah pada kotak (box) akan cenderung berada pada bagian bawah plot, menunjukkan bahwa median nilai-nilai adalah rendah.
#
# 2. Kuartil Bawah (Q1) dan Kuartil Atas (Q3) yang rendah: Bagian bawah dan bagian atas kotak juga akan cenderung berada pada bagian bawah plot, menunjukkan bahwa mayoritas nilai-nilai berada di bagian bawah rentang data.
#
# 3. 'Kumis' (whiskers) yang pendek: 'Kumis' atas dan 'kumis' bawah akan cenderung pendek atau mungkin tidak terlihat sama sekali, menunjukkan bahwa sebagian besar nilai-nilai berada dalam jarak yang relatif kecil dari median.
#
# Ini bisa mengindikasikan distribusi data yang condong ke kiri, di mana sebagian besar nilai berada di bagian bawah rentang data. Hal ini dapat disebabkan oleh beberapa faktor, seperti adanya nilai-nilai outlier yang memiliki nilai yang jauh lebih tinggi dari mayoritas data.

# %%
fig, axs = plt.subplots(2, 7, figsize=(20, 10))

axs = axs.flatten()

for i in range(len(nums)):
    sns.kdeplot(data_product2[nums[i]], color='blue', ax=axs[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insight data distribution
#
# 1. Subplot di Kiri:
#
# Ini adalah subplot pertama dalam satu baris.
# Fitur-fitur yang ditampilkan, seperti 'Administrative', 'Administrative_Duration', 'Informational', 'Informational_Duration', 'BounceRates', 'ExitRates', 'PageValues', dan 'SpecialDay', akan ditempatkan di sini.
# Dalam konteks "skew ke kiri", ini mengindikasikan bahwa distribusi data untuk fitur-fitur ini mungkin memiliki kecenderungan untuk condong ke kiri (skewed left), artinya nilai-nilai yang lebih kecil lebih umum daripada nilai-nilai yang lebih besar.
#
# 2. Subplot di Tengah:
#
# Ini adalah subplot kedua dalam satu baris.
# Fitur 'ProductRelated' akan ditempatkan di sini.
# Dalam konteks "skew di tengah", tidak ada arti khusus yang terkait dengan istilah ini. Ini hanya menunjukkan bahwa fitur 'ProductRelated' ditempatkan di tengah antara subplot kiri dan kanan.
#
# 3. Subplot di Kanan:
#
# Ini adalah subplot ketiga dalam satu baris.
# Fitur 'ProductRelated_Duration' akan ditempatkan di sini.
# Dalam konteks "skew ke kanan", ini menunjukkan bahwa distribusi data untuk fitur ini mungkin memiliki kecenderungan untuk condong ke kanan (skewed right), artinya nilai-nilai yang lebih besar lebih umum daripada nilai-nilai yang lebih kecil.

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# ## Heat Map

# %%
num_heat = data_product2.select_dtypes(exclude='object')

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(num_heat.corr(), cmap='Blues', annot=True, fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# ## Insight Heat Map
#
# Heatmap adalah visualisasi yang berguna untuk menampilkan hubungan atau korelasi antara dua set data. Dalam konteks yang Anda berikan, heatmap sepertinya menampilkan korelasi antara fitur-fitur tertentu dengan fitur 'revenue'. Mari kita jelaskan setiap poin yang Anda sebutkan:
#
# 1. PageValues dan Revenue memiliki nilai paling tinggi pertama yaitu 0.50:
#
# Ini menunjukkan bahwa ada korelasi positif yang kuat antara fitur PageValues (nilai halaman) dan Revenue. Artinya, semakin tinggi nilai PageValues, semakin besar kemungkinan pengunjung akan menghasilkan pendapatan.
#
# 2. ProductRelated dan Revenue memiliki nilai tinggi ke 2 yaitu 0.16:
#
# Ini menunjukkan bahwa ada korelasi positif antara fitur ProductRelated (kunjungan terkait produk) dan Revenue, meskipun korelasinya tidak sekuat dengan PageValues.
#
# 3. ProductRelated Duration dan Revenue memiliki nilai tinggi ke 3 yaitu 0.16:
#
# Korelasi positif yang sama dengan ProductRelated juga terjadi antara ProductRelated Duration (durasi kunjungan terkait produk) dan Revenue.
#
# 4. Exit Rate dan Revenue memiliki nilai paling rendah yaitu -0.21:
#
# Ini menunjukkan bahwa ada korelasi negatif yang cukup kuat antara Exit Rate (tingkat keluar) dan Revenue. Artinya, semakin tinggi tingkat keluar, semakin kecil kemungkinan pengunjung akan menghasilkan pendapatan.
#
# 5. Bounce Rate dan Revenue memiliki nilai rendah ke 2 yaitu -0.15:
#
# Korelasi negatif juga terjadi antara Bounce Rate (tingkat pentalan) dan Revenue. Semakin tinggi tingkat pentalan, semakin kecil kemungkinan pengunjung akan menghasilkan pendapatan.
#
# 6. Visitor Type dan Revenue memiliki nilai rendah ke 3 yaitu -0.10:
#
# Korelasi negatif antara Visitor Type (tipe pengunjung) dan Revenue menunjukkan bahwa jenis pengunjung tertentu mungkin memiliki dampak negatif terhadap pendapatan.

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Outliers

# %%
for num in nums:
  if num not in ['Administrative', 'BounceRates', 'ExitRates', 'SpecialDay','OperatingSystems', 'Browser', 'Region', 'TrafficType']:
    data_product2[num] = np.log(data_product2[num] + (data_product2[data_product2[num] > 0][num].min() / 2)) # kita harus pastikan data tidak 0 untuk dilogtransform

# %%
import math

plt.figure(figsize=(12, 8))
for i in range (0, len(nums)):
  plt.subplot(math.ceil(len(nums)/3), 3, i+1)
  sns.violinplot(data=data_product2, y=nums[i], x='Revenue', linewidth=2, orient='v')

# %% [markdown]
# ## Insight Outliers
#
# Dengan melakukan transformasi log, Anda mencoba untuk mengurangi skewness atau perbedaan yang besar antara nilai-nilai dalam fitur tersebut. Transformasi log digunakan khususnya ketika data memiliki distribusi yang condong (skewed), di mana nilai-nilai terkonsentrasi pada salah satu ujung rentang nilai.
#
# Dengan melakukan log transformation pada fitur-fitur yang memiliki outliers, Anda dapat mencoba untuk:
#
# 1. Mengurangi Pengaruh Outliers:
#
# Outliers dapat memiliki pengaruh yang signifikan pada analisis statistik atau model pembelajaran mesin. Melakukan transformasi log dapat membantu mengurangi dampak outliers karena nilai-nilai ekstrem cenderung "ditarik" lebih dekat ke nilai-nilai tengah setelah transformasi.
#
# 2. Mengurangi Skewness:
#
# Transformasi log sering digunakan untuk mengurangi skewness dalam distribusi data. Ketika data memiliki skewness yang signifikan, ini dapat menyebabkan kesalahan dalam analisis statistik dan pemodelan.

# %% [markdown]
# # Business Insight

# %% [markdown]
# ### Menambah Fitur Target berdasarkan Revenue

# %%
data_product2['Target'] = data_product2['Revenue'].apply(lambda x: 'Buyer' if x == True else 'Non-Buyer')

# %%
data_product2['Target'].unique()
# Out:
# array(['Non-Buyer', 'Buyer'], dtype=object)

# %%
df_target_grp = data_product2.groupby(['Target']).agg(vist_cnt = ('Target', 'count')).sort_values('vist_cnt', ascending=True)
df_target_grp.reset_index(inplace=True)

df_target_grp['Percentage'] = round(df_target_grp['vist_cnt']/df_target_grp['vist_cnt'].sum()*100,2)
df_target_grp
# Out:
#       Target  vist_cnt  Percentage
# 0      Buyer      2008       15.51
# 1  Non-Buyer     10938       84.49

# %%
# Create barplot for Target
ax_diff = sns.barplot(x='Target', y='Percentage', data=df_target_grp, palette='OrRd')

# Annotate the bar with the value
for p in ax_diff.patches:
    ax_diff.annotate(f"{p.get_height():.2f}%", (p.get_x() + p.get_width() / 2., p.get_height()),
                     ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                     textcoords='offset points')

# Formatting plot
plt.ylim(0, 100)
plt.title('Generate revenue by visitor status')
plt.xlabel('Visitor status',fontsize=12)
plt.ylabel('Percentage by Total Clients',fontsize=12)
plt.show()

# %% [markdown]
# ### Insight Menambah Fitur Target berdasarkan Revenue
#
# Mengubah kolom 'Revenue' menjadi target dengan label 'Non-Buyer' dan 'Buyer' mengindikasikan proses pembentukan variabel target untuk keperluan pemodelan atau analisis. Dalam kasus ini, terdapat dua label yang mungkin untuk variabel target:
#
# 1. Non-Buyer:
#
# - Ini merujuk pada pengunjung yang tidak melakukan pembelian di situs web atau platform yang dianalisis. Ini mencakup pengunjung yang hanya melakukan penjelajahan atau interaksi tanpa melakukan transaksi pembelian.
#
# - Terdapat 2008 pengunjung (15.51% dari total), yang berarti sebanyak 2008 pengunjung yang melakukan pembelian.
#
# 2. Buyer:
#
# - Ini merujuk pada pengunjung yang melakukan pembelian di situs web atau platform yang dianalisis. Ini mencakup pengunjung yang melakukan transaksi pembelian setelah melakukan penjelajahan atau interaksi di situs tersebut.
#
# - Terdapat 10938 pengunjung (84.49% dari total), yang berarti sebanyak 10938 pengunjung yang tidak melakukan pembelian.

# %%
for index, row in data_product2.iterrows():
    if row['PageValues'] <=0:
        data_product2.at[index, 'Page_categories'] = 'Poor'
    elif row['PageValues'] <=2:
        data_product2.at[index, 'Page_categories'] = 'Mixed'
    elif row['PageValues'] <=4:
        data_product2.at[index, 'Page_categories'] = 'Good'
    else:
        data_product2.at[index, 'Page_categories'] = 'Excellent'

# %%
data_product2['Page_categories'].value_counts()
# Out:
# Page_categories
# Poor         10151
# Good          1771
# Mixed          668
# Excellent      356
# Name: count, dtype: int64

# %%
df_pages_grp = data_product2.groupby(['Page_categories', 'Target']).agg(vist_cnt = ('Target', 'count')).sort_values('vist_cnt', ascending=False)
df_pages_grp.reset_index(inplace=True)

df_pages_grp['Percentage'] = round(df_pages_grp['vist_cnt']/df_pages_grp['vist_cnt'].sum()*100,2)
df_pages_grp
# Out:
#   Page_categories     Target  vist_cnt  Percentage
# 0            Poor  Non-Buyer      9741       75.24
# 1            Good      Buyer      1063        8.21
# 2            Good  Non-Buyer       708        5.47
# 3           Mixed  Non-Buyer       422        3.26
# 4            Poor      Buyer       410        3.17
# 5       Excellent      Buyer       289        2.23
# 6           Mixed      Buyer       246        1.90
# 7       Excellent  Non-Buyer        67        0.52

# %%
# Create barplot for Target
ax_page = sns.barplot(x='Page_categories', y='Percentage', hue='Target', data=df_pages_grp, palette='OrRd_r')

# Annotate the bar with the value
for p in ax_page.patches:
    ax_page.annotate(f"{p.get_height():.2f}%", (p.get_x() + p.get_width() / 2., p.get_height()),
                         ha='center', va='center', fontsize=15, color='black', xytext=(0, 15),
                         textcoords='offset points')

# Formatting plot
plt.ylim(0, 100)
plt.title('Visitor status by Page Rating')
plt.xlabel('Page Rating', fontsize=12)
plt.ylabel('Percentage by Total Clients', fontsize=12)
plt.show()

# %% [markdown]
# #### Insight:
# - 75.24% of total visitor who visits a page with poor rating ended up choosing not to proceed with the transaction, with only 3.17% of visitors in this category choose to proceed. This indicates that visitors purchasing intention might be influenced by wether the pages they visit before they decide to proceed with the transaction are able to peak their interest. This suggests that having higher rating on pages that visitors might visit can be beneficial in influencing visitors as potential buyer.
# - Pages in the categories of Good and Excellent have around 2% to 3% more visitors choosing to proceed with the transaction compared to the total visitors who choose not to proceed in these categories, with each at 5.47% and 0.52% respectively. This indicates that having a higher rating for a page does influence visitors' purchasing intentions. This also suggests that a highly rated page might have the content and information that visitors need in their endeavor, which ultimately encourages visitors to continue their purchase.
# - More than 3% of visitors who previously visited a page with mixed ratings ended up choosing not to proceed with the transaction, with only a little less than 2% choosing to proceed. This indicates that if a page contains elements that can be considered both bad and good, visitors might be more biased towards the negative elements, causing them to outweigh the positive elements and ultimately impacting their decision to purchase.

# %% [markdown]
# ### Menambah Fitur Weekend status Berdasarkan Weekend

# %%
data_product2['Weekend_status'] = data_product2['Weekend'].apply(lambda x: 'Week-end' if x == True else 'Week-day')

# %%
data_product2['Weekend_status'].unique()
# Out:
# array(['Week-day', 'Week-end'], dtype=object)

# %%
df_weekstat_grp = data_product2.groupby(['Weekend_status', 'Target']).agg(vist_cnt = ('Target', 'count')).sort_values('vist_cnt', ascending=False)
df_weekstat_grp.reset_index(inplace=True)

df_weekstat_grp['Percentage'] = round(df_weekstat_grp['vist_cnt']/df_weekstat_grp['vist_cnt'].sum()*100,2)
df_weekstat_grp
# Out:
#   Weekend_status     Target  vist_cnt  Percentage
# 0       Week-day  Non-Buyer      8449       65.26
# 1       Week-end  Non-Buyer      2489       19.23
# 2       Week-day      Buyer      1480       11.43
# 3       Week-end      Buyer       528        4.08

# %%
# Create barplot for Target
ax_weekstat = sns.barplot(x='Weekend_status', y='Percentage', hue='Target', data=df_weekstat_grp, palette='OrRd_r')

# Annotate the bar with the value
for p in ax_weekstat.patches:
    ax_weekstat.annotate(f"{p.get_height():.2f}%", (p.get_x() + p.get_width() / 2., p.get_height()),
                         ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                         textcoords='offset points')

# Formatting plot
plt.ylim(0, 100)
plt.title('Visitor status by day')
plt.xlabel('day status', fontsize=12)
plt.ylabel('Percentage by Total Clients', fontsize=12)
plt.show()

# %% [markdown]
# ### Insight Menambah Fitur Weekend status Berdasarkan Weekend
#
# Dengan mengubah kolom 'Weekend' menjadi 'Weekend_status' yang memiliki dua label, yaitu 'Week-day' dan 'Week-end', kita dapat melihat perbedaan perilaku pembelian pengunjung antara hari kerja dan akhir pekan.
#
# Berikut adalah insight dari data yang telah diubah:
#
# 1. Week-day (Hari Kerja):
#
# - Jumlah pengunjung yang menjadi 'Non-Buyer' pada hari kerja adalah 8449 (65.26% dari total pengunjung).
# - Jumlah pengunjung yang menjadi 'Buyer' pada hari kerja adalah 1480 (11.43% dari total pengunjung).
# - Dapat dilihat bahwa sebagian besar pengunjung pada hari kerja cenderung menjadi 'Non-Buyer', sementara persentase pengunjung yang menjadi 'Buyer' relatif lebih rendah.
#
# 2. Week-end (Akhir Pekan):
#
# - Jumlah pengunjung yang menjadi 'Non-Buyer' pada akhir pekan adalah 2489 (19.23% dari total pengunjung).
# - Jumlah pengunjung yang menjadi 'Buyer' pada akhir pekan adalah 528 (4.08% dari total pengunjung).
# - Insight menarik yang dapat ditarik adalah bahwa, meskipun jumlah total pengunjung pada akhir pekan lebih sedikit dibandingkan dengan hari kerja, persentase pengunjung yang menjadi 'Buyer' pada akhir pekan relatif lebih tinggi dibandingkan dengan hari kerja. Hal ini menunjukkan bahwa pengunjung cenderung lebih cenderung melakukan pembelian pada akhir pekan.

# %% [markdown]
# ### Insight Weekend Status VS Target
#
# Business Insight:
# 1. Polap Pembelian Berdasarkan Hari dalam Seminggu:
#
# - Analisis menurut hari dalam seminggu menunjukkan bahwa terdapat perbedaan perilaku pembelian antara hari kerja dan akhir pekan. Sebagian besar pengunjung pada hari kerja cenderung menjadi 'Non-Buyer', sementara persentase pengunjung yang menjadi 'Buyer' relatif lebih tinggi pada akhir pekan.
#
# 2. Potensi Pembelian pada Akhir Pekan:
#
# - Meskipun jumlah total pengunjung pada akhir pekan lebih sedikit daripada hari kerja, persentase pengunjung yang melakukan pembelian relatif lebih tinggi pada akhir pekan. Ini menunjukkan bahwa akhir pekan memiliki potensi penjualan yang signifikan dan mungkin merupakan waktu yang strategis untuk meluncurkan promosi atau penawaran khusus.
#
# Recommendation:
# - Optimalkan Strategi Pemasaran pada Akhir Pekan:
# - Personalisasi Pengalaman Pembelian pada Hari Kerja:

# %% [markdown]
# ### Menambah Fitur Special Day Category Berdasarkan Special Day

# %%
for index, row in data_product2.iterrows():
    if row['SpecialDay'] <=0.2:
        data_product2.at[index, 'SpecialD_Category'] = 'Close'
    elif row['SpecialDay'] <=0.4:
        data_product2.at[index, 'SpecialD_Category'] = 'Moderate'
    elif row['SpecialDay'] <=1:
        data_product2.at[index, 'SpecialD_Category'] = 'Far'

# %%
df_speciald_grp = data_product2.groupby(['Target', 'SpecialD_Category']).agg(vist_cnt = ('Target', 'count')).sort_values('vist_cnt', ascending=False)
df_speciald_grp.reset_index(inplace=True)

df_speciald_grp['Percentage'] = round(df_speciald_grp['vist_cnt']/df_speciald_grp['vist_cnt'].sum()*100,2)
df_speciald_grp
# Out:
#       Target SpecialD_Category  vist_cnt  Percentage
# 0  Non-Buyer             Close      9883       76.34
# 1      Buyer             Close      1939       14.98
# 2  Non-Buyer               Far       816        6.30
# 3  Non-Buyer          Moderate       239        1.85
# 4      Buyer               Far        55        0.42
# 5      Buyer          Moderate        14        0.11

# %%
# Create barplot for Target
ax_spec_diff = sns.barplot(x='SpecialD_Category', y='Percentage', hue='Target', data=df_speciald_grp, palette='OrRd_r')

# Annotate the bar with the value
for p in ax_spec_diff.patches:
    ax_spec_diff.annotate(f"{p.get_height():.2f}%", (p.get_x() + p.get_width() / 2., p.get_height()),
                          ha='center', va='center', fontsize=15, color='black', xytext=(0, 5),
                          textcoords='offset points')

# Formatting plot
plt.ylim(0, 100)
plt.title('Visitor status by proximity to special day')
plt.xlabel('Proximity to special day', fontsize=12)
plt.ylabel('Percentage of visitors', fontsize=12)
plt.show()

# %% [markdown]
# ### Insight Menambah Fitur Special Day Category Berdasarkan Special Day
#
# Insight dari menambahkan fitur 'SpecialD_Category' berdasarkan nilai 'Special Day' adalah sebagai berikut:
#
# Close (Dekat):
#
# - Jumlah pengunjung yang menjadi 'Non-Buyer' dan dikategorikan sebagai 'Close' adalah 9883 (76.34% dari total pengunjung).
# - Jumlah pengunjung yang menjadi 'Buyer' dan dikategorikan sebagai 'Close' adalah 1939 (14.98% dari total pengunjung).
# - Ini menunjukkan bahwa sebagian besar pengunjung yang mengunjungi situs web pada hari yang memiliki 'Special Day' yang dekat (≤ 0.2) cenderung menjadi 'Non-Buyer', meskipun masih ada jumlah yang signifikan yang menjadi 'Buyer'.
#
# Moderate (Sedang):
#
# - Jumlah pengunjung yang menjadi 'Non-Buyer' dan dikategorikan sebagai 'Moderate' adalah 239 (1.85% dari total pengunjung).
# - Jumlah pengunjung yang menjadi 'Buyer' dan dikategorikan sebagai 'Moderate' adalah 14 (0.11% dari total pengunjung).
# - Ini menunjukkan bahwa 'Special Day' yang memiliki pengaruh moderat pada perilaku pembelian, dengan jumlah pengunjung yang menjadi 'Buyer' yang lebih rendah dibandingkan dengan kategori 'Close', tetapi lebih tinggi dibandingkan dengan kategori 'Far'.
#
# Far (Jauh):
#
# - Jumlah pengunjung yang menjadi 'Non-Buyer' dan dikategorikan sebagai 'Far' adalah 816 (6.30% dari total pengunjung).
# - Jumlah pengunjung yang menjadi 'Buyer' dan dikategorikan sebagai 'Far' adalah 55 (0.42% dari total pengunjung).
# - Ini menunjukkan bahwa jumlah pengunjung yang menjadi 'Buyer' pada hari dengan 'Special Day' yang jauh (≤ 1) adalah yang terendah, menunjukkan bahwa 'Special Day' yang jauh cenderung memiliki dampak yang lebih rendah pada perilaku pembelian.

# %% [markdown]
# ### Insight Special Day Category VS Target
#
# Business Insight:
# 1. Pengaruh Hari Khusus pada Perilaku Pembelian:
#
# - Analisis kategorisasi 'Special Day' memberikan wawasan tentang bagaimana hari khusus memengaruhi perilaku pembelian pengunjung. Ini dapat membantu dalam memahami pola pembelian selama periode tertentu dan merencanakan strategi pemasaran yang lebih efektif.
# - Segmentasi pelanggan berdasarkan kategori 'Special Day' memungkinkan untuk penargetan yang lebih spesifik dan personalisasi pesan atau penawaran sesuai dengan tingkat pengaruh 'Special Day' pada perilaku pembelian masing-masing segmen.
#
# Recommendation:
# - Penyesuaian Strategi Pemasaran
# - Peningkatan Keterlibatan pada Hari Khusus

# %%
df_vistype_grp = data_product2.groupby(['Target', 'VisitorType']).agg(vist_cnt = ('Target', 'count')).sort_values('vist_cnt', ascending=False)
df_vistype_grp.reset_index(inplace=True)

df_vistype_grp['Percentage'] = round(df_vistype_grp['vist_cnt']/df_vistype_grp['vist_cnt'].sum()*100,2)
df_vistype_grp
# Out:
#       Target        VisitorType  vist_cnt  Percentage
# 0  Non-Buyer  Returning_Visitor      9520       73.54
# 1      Buyer  Returning_Visitor      1552       11.99
# 2  Non-Buyer        New_Visitor      1345       10.39
# 3      Buyer        New_Visitor       440        3.40
# 4  Non-Buyer              Other        73        0.56
# 5      Buyer              Other        16        0.12

# %%
import plot_text as pt
## Create barplot for Target
ax_vistype_diff = sns.barplot(x='VisitorType', y='Percentage',hue='Target', data=df_vistype_grp, palette='OrRd_r')

for p in ax_vistype_diff.patches:
    ax_vistype_diff.annotate(f"{p.get_height():.2f}%", (p.get_x() + p.get_width() / 2., p.get_height()),
                          ha='center', va='center', fontsize=15, color='black', xytext=(0, 10),
                          textcoords='offset points')

# Formatting plot
plt.ylim(0, 100)
plt.title('Visitors frequency by visitor types')
plt.xlabel('Visitor Types',fontsize=12)
plt.ylabel('Percentage by Total Clients',fontsize=12)
# Out:
# Text(0, 0.5, 'Percentage by Total Clients')

# %% [markdown]
# ### Insight Menambah Fitur Visitor Types Berdasarkan Target
#
# Insight dari penambahan fitur 'VisitorType' berdasarkan target adalah sebagai berikut:
#
# Returning Visitor:
#
# - Jumlah pengunjung yang merupakan 'Non-Buyer' dan merupakan 'Returning Visitor' adalah 9520, yang menyumbang 73.54% dari total pengunjung.
# - Jumlah pengunjung yang merupakan 'Buyer' dan merupakan 'Returning Visitor' adalah 1552, yang menyumbang 11.99% dari total pengunjung.
# - Ini menunjukkan bahwa sebagian besar pengunjung yang merupakan 'Returning Visitor' cenderung menjadi 'Non-Buyer', meskipun masih ada jumlah yang signifikan yang menjadi 'Buyer'.
#
# New Visitor:
#
# - Jumlah pengunjung yang merupakan 'Non-Buyer' dan merupakan 'New Visitor' adalah 1345, yang menyumbang 10.39% dari total pengunjung.
# - Jumlah pengunjung yang merupakan 'Buyer' dan merupakan 'New Visitor' adalah 440, yang menyumbang 3.40% dari total pengunjung.
# - Dapat dilihat bahwa sebagian besar pengunjung yang merupakan 'New Visitor' cenderung menjadi 'Non-Buyer', sementara persentase pengunjung yang menjadi 'Buyer' relatif lebih rendah.
#
# Others:
#
# - Jumlah pengunjung yang merupakan 'Non-Buyer' dan merupakan 'Others' adalah 73, yang menyumbang 0.56% dari total pengunjung.
# - Jumlah pengunjung yang merupakan 'Buyer' dan merupakan 'Others' adalah 16, yang menyumbang 0.12% dari total pengunjung.
# - Ini menunjukkan bahwa jumlah pengunjung yang merupakan 'Others' (bukan 'New Visitor' atau 'Returning Visitor') memiliki kontribusi yang sangat rendah dalam pembelian, baik sebagai 'Non-Buyer' maupun 'Buyer'.

# %% [markdown]
# ### Insight Fitur Visitor Types VS Target
#
# Business Insight:
#
# 1. Polap Pembelian Berdasarkan Tipe Pengunjung:
#
# - Pengunjung yang merupakan 'Returning Visitor' cenderung lebih sering menjadi 'Non-Buyer' daripada 'Buyer', meskipun ada sebagian yang signifikan yang melakukan pembelian. Hal ini menunjukkan perlunya fokus pada strategi retensi pelanggan untuk meningkatkan konversi dari pengunjung yang kembali.
# - Pengunjung yang merupakan 'New Visitor' juga cenderung menjadi 'Non-Buyer' dalam proporsi yang tinggi, menunjukkan bahwa ada peluang untuk meningkatkan pengalaman pembelian bagi pengunjung baru guna meningkatkan konversi.
# - Pengunjung yang termasuk dalam kategori 'Others' memiliki kontribusi yang sangat rendah dalam pembelian, baik sebagai 'Non-Buyer' maupun 'Buyer', sehingga perlu untuk memperjelas dan memahami perilaku mereka untuk menentukan strategi yang lebih tepat.
#
# 2. Perilaku Pembelian dan Retensi Pelanggan:
#
# - Analisis pengunjung berdasarkan tipe memberikan wawasan tentang perilaku pembelian dan kontribusi relatif dari masing-masing kelompok. Ini dapat membantu dalam mengembangkan strategi pemasaran dan retensi pelanggan yang lebih terfokus.
#
# Recommendation:
# - Personalisasi Pengalaman Pengunjung
# - Strategi Retensi Pelanggan
# - Peningkatan Pengalaman Pengguna Baru
# - Analisis Lebih Lanjut terhadap Pengunjung Kategori 'Others'

# %%
data_product2['Bounces_to_exit_ratio'] = data_product2['BounceRates']/data_product2['ExitRates']

# %%
for index, row in data_product2.iterrows():
    if row['Bounces_to_exit_ratio'] <1:
        data_product2.at[index, 'Bouncestoexit_category'] = 'Likely to Exit'
    elif row['Bounces_to_exit_ratio'] == 1:
        data_product2.at[index, 'Bouncestoexit_category'] = 'Neutral'
    elif row['Bounces_to_exit_ratio'] >1:
        data_product2.at[index, 'Bouncestoexit_category'] = 'Likely to Bounces'
    else:
        data_product2.at[index, 'Bouncestoexit_category'] = 'Neutral'

# %%
data_product2['Bouncestoexit_category'].value_counts()
# Out:
# Bouncestoexit_category
# Likely to Exit       11767
# Neutral                999
# Likely to Bounces      180
# Name: count, dtype: int64

# %%
df_vistbounces_grp = data_product2.groupby(['VisitorType','Bouncestoexit_category']).agg(vist_cnt=('VisitorType','count')).sort_values('vist_cnt', ascending=False)
df_vistbounces_grp.reset_index(inplace=True)

df_vistbounces_grp['Percentage'] = round(df_vistbounces_grp['vist_cnt']/df_vistbounces_grp['vist_cnt'].sum()*100,2)
df_vistbounces_grp
# Out:
#          VisitorType Bouncestoexit_category  vist_cnt  Percentage
# 0  Returning_Visitor         Likely to Exit     10031       77.48
# 1        New_Visitor         Likely to Exit      1665       12.86
# 2  Returning_Visitor                Neutral       883        6.82
# 3  Returning_Visitor      Likely to Bounces       158        1.22
# 4        New_Visitor                Neutral        99        0.76
# 5              Other         Likely to Exit        71        0.55
# 6        New_Visitor      Likely to Bounces        21        0.16
# 7              Other                Neutral        17        0.13
# 8              Other      Likely to Bounces         1        0.01

# %%
## Create barplot for Target
ax_vistbounces_ratio = sns.barplot(x='VisitorType', y='Percentage',hue='Bouncestoexit_category', data=df_vistbounces_grp, palette='OrRd_r')

for p in ax_vistbounces_ratio.patches:
    ax_vistbounces_ratio.annotate(f"{p.get_height():.2f}%", (p.get_x() + p.get_width() / 2., p.get_height()),
                          ha='center', va='center', fontsize=15, color='black', xytext=(0, 10),
                          textcoords='offset points')

# Formatting plot
plt.ylim(0, 80)
plt.title('Bounces to exit ratio by visitor types')
plt.xlabel('Visitor Types',fontsize=12)
plt.ylabel('Percentage by Total Clients',fontsize=12)
# Out:
# Text(0, 0.5, 'Percentage by Total Clients')

# %% [markdown]
# ### Insight:
#
# - The majority of visitors who are more likely to exit are returning visitors, reaching 77.48% of total visitors. Only 1.22% are likely to bounce, and 6.82% are neutral. This is an expected result because returning visitors are likely already familiar with the site layout and have a specific goal in mind, such as checking order status and current event. This also suggests that the site is able to facilitate quick responses so that visitors can find the information they need efficiently.
# - 12.86% of visitors who are more likely to exit are new visitors, and among new visitors, those who are likely to bounce are much fewer in comparison, with only 0.16% of total visitors. This finding raises a concern about the possible lack of engagement and perceived interest that would keep new visitors exploring for an extended period of time. This suggests that the page that the new visitor initially landed on could be lacking in information or functionality that the new visitors are looking for."

# %% [markdown]
# ### Product Related Duration VS Revenue

# %%
# Menghapus spasi ekstra dari nama kolom
data_product2.columns = data_product2.columns.str.strip()

# Mengatur ukuran plot
plt.figure(figsize=(8, 6))

# Membuat histogram
sns.histplot(data=data_product2, x='ProductRelated_Duration', hue='Revenue', multiple='stack')

# Menambahkan label
plt.xlabel('ProductRelated_Duration')
#plt.xlim(0,8000)
plt.ylabel('Count')
plt.title('Histogram of ProductRelated_Duration by Revenue')

# Menampilkan plot
plt.show()

# %% [markdown]
# ### Insight Product Related Duration VS Revenue
#
# Jika durasi yang dihabiskan oleh pengguna pada halaman terkait produk ('Product Related Duration') memiliki skew ke kanan (artinya distribusinya condong ke nilai-nilai yang lebih tinggi) dan jumlah pendapatan ('Revenue') masih jauh dari merata antara kategori 'Buyer' dan 'Non-Buyer', ini mengindikasikan adanya potensi untuk meningkatkan konversi pembelian.
#
# 1. Business Insight:
#
# - Durasi yang dihabiskan oleh pengguna pada halaman terkait produk ('Product Related Duration') yang condong ke nilai yang lebih tinggi menunjukkan minat yang kuat dari pengguna terhadap produk atau layanan yang ditawarkan.
# - Namun, meskipun minat ini tinggi, jumlah pendapatan ('Revenue') dari pengguna yang melakukan pembelian ('Buyer') masih jauh lebih rendah daripada yang tidak ('Non-Buyer').
#
# 2. Recommendation:
#
# - Optimalkan Pengalaman Pengguna
# - Personalisasi dan Rekomendasi Produk

# %% [markdown]
# ### Exit Rates & Bounce Rate VS Revenue

# %%
# Menghapus spasi ekstra dari nama kolom
data_product2.columns = data_product2.columns.str.strip()

# Mengatur ukuran plot
plt.figure(figsize=(8, 6))

# Membuat histogram
sns.histplot(data=data_product2, x='ExitRates', hue='Revenue', multiple='stack')

# Menambahkan label
plt.xlabel('ExitRates')
plt.ylabel('Count')
plt.title('Histogram of ProductRelated by Revenue')

# Menampilkan plot
plt.show()

# %%
# Menghapus spasi ekstra dari nama kolom
data_product2.columns = data_product2.columns.str.strip()

# Mengatur ukuran plot
plt.figure(figsize=(8, 6))

# Membuat histogram
sns.histplot(data=data_product2, x='BounceRates', hue='Revenue', multiple='stack')

# Menambahkan label
plt.xlabel('BounceRates')
plt.ylabel('Count')
plt.title('Histogram of BounceRates by Revenue')

# Menampilkan plot
plt.show()

# %% [markdown]
# ### Insight Exit Rates & Bounce Rate VS Revenue
#
#
# Jika tingkat keluar dari halaman produk ('Exit Rate & Bounce Rate') memiliki skew ke kiri (artinya distribusinya condong ke nilai-nilai yang lebih rendah) dan jumlah pendapatan ('Revenue') masih jauh lebih rendah dari yang diharapkan, ini mengindikasikan adanya potensi masalah dalam proses pembelian atau pengalaman pengguna yang perlu diperbaiki.
#
# 1. Business Insight:
#
# - Tingkat keluar yang rendah dari halaman produk ('Exit Rate & Bounce Rate') menunjukkan bahwa pengguna cenderung tinggal lebih lama di halaman tersebut, yang seharusnya meningkatkan kemungkinan pembelian.
# - Namun, meskipun pengguna tinggal lebih lama, jumlah pendapatan ('Revenue') masih jauh lebih rendah dari yang diharapkan, menunjukkan bahwa ada masalah dalam mengubah minat pengguna menjadi tindakan pembelian.
#
# 2. Recommendation:
# - Analisis dan Perbaikan Proses Pembelian
# - Personalisasi dan Rekomendasi Produk
# - Analisis Pelanggan yang Telah Keluar

# %%
data_product2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12946 entries, 0 to 12945
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Administrative           12835 non-null  float64
#  1   Administrative_Duration  12313 non-null  float64
#  2   Informational            12946 non-null  float64
#  3   Informational_Duration   12946 non-null  float64
#  4   ProductRelated           12946 non-null  float64
#  5   ProductRelated_Duration  12307 non-null  float64
#  6   BounceRates              12872 non-null  float64
#  7   ExitRates                12946 non-null  float64
#  8   PageValues               12946 non-null  float64
#  9   SpecialDay               12946 non-null  float64
#  10  Month                    12946 non-null  object
#  11  OperatingSystems         12422 non-null  float64
#  12  Browser                  12946 non-null  int64
#  13  Region                   12946 non-null  int64
#  14  TrafficType              12946 non-null  int64
#  15  VisitorType              12946 non-null  object
#  16  Weekend                  12946 non-null  bool
#  17  Revenue                  12946 non-null  bool
#  18  Target                   12946 non-null  object
#  19  Page_categories          12946 non-null  object
#  20  Weekend_status           12946 non-null  object
#  21  SpecialD_Category        12946 non-null  object
#  22  Bounces_to_exit_ratio    12790 non-null  float64
#  23  Bouncestoexit_category   12946 non-null  object
# dtypes: bool(2), float64(12), int64(3), object(7)
# memory usage: 2.2+ MB

# %% [markdown]
# # Features Cleansing

# %% [markdown]
# ## Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# Misalkan data_product adalah DataFrame Anda
# Gantilah 'data_product' dengan nama DataFrame yang sesuai

# Membuat objek LabelEncoder
label_encoder = LabelEncoder()

# Menggunakan LabelEncoder untuk mengubah nilai kategorikal menjadi numerik
data_product['Month'] = label_encoder.fit_transform(data_product['Month'])
data_product['VisitorType'] = label_encoder.fit_transform(data_product['VisitorType'])
data_product['Weekend'] = label_encoder.fit_transform(data_product['Weekend'])
data_product['Revenue'] = label_encoder.fit_transform(data_product['Revenue'])

# Menampilkan DataFrame setelah perubahan
display(data_product)
# Out:
#        Administrative  Administrative_Duration  Informational  \
# 0                 0.0                 0.000000              0
# 1                 0.0                 0.000000              0
# 2                 0.0                 0.000000              0
# 3                 0.0                      NaN              0
# 4                 0.0                 0.000000              0
# ...               ...                      ...            ...
# 12941             0.0                 0.000000              0
# 12942             0.0                 0.000000              0
# 12943            14.0               484.461579              2
# 12944             3.0                60.833333              0
# 12945             0.0                 0.000000              0
#
#        Informational_Duration  ProductRelated  ProductRelated_Duration  \
# 0                         0.0               1                 0.000000
# 1                         0.0               2                64.000000
# 2                         0.0               1                 0.000000
# 3                         0.0               2                 2.666667
# 4                         0.0              10               627.500000
# ...                       ...             ...                      ...
# 12941                     0.0               2                 0.000000
# 12942                     0.0              59              1309.658333
# 12943                    14.0              33               898.491579
# 12944                     0.0              18               884.633333
# 12945                     0.0               6               241.000000
#
#        BounceRates  ExitRates  PageValues  SpecialDay  Month  \
# 0         0.200000   0.200000         0.0         0.0      2
# 1         0.000000   0.100000         0.0         0.0      2
# 2         0.200000   0.200000         0.0         0.0      2
# 3         0.050000   0.140000         0.0         0.0      2
# 4         0.020000   0.050000         0.0         0.0      2
# ...            ...        ...         ...         ...    ...
# 12941     0.200000   0.200000         0.0         0.0      7
# 12942     0.017241   0.030879         0.0         0.0      1
# 12943     0.004269   0.034661         0.0         0.0      9
# 12944     0.021053   0.041140         0.0         0.0      5
# 12945     0.000000   0.033333         0.0         0.0      6
#
#        OperatingSystems  Browser  Region  TrafficType  VisitorType  Weekend  \
# 0                   1.0        1       1            1            2        0
# 1                   2.0        2       1            2            2        0
# 2                   4.0        1       9            3            2        0
# 3                   3.0        2       2            4            2        0
# 4                   3.0        3       1            4            2        1
# ...                 ...      ...     ...          ...          ...      ...
# 12941               3.0        2       1           13            2        0
# 12942               3.0        2       3            1            2        0
# 12943               1.0        8       1            3            2        0
# 12944               2.0        2       3           10            2        0
# 12945               2.0       10       2            3            2        0
#
#        Revenue
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 12941        0
# 12942        0
# 12943        0
# 12944        0
# 12945        0
#
# [12946 rows x 18 columns]

# %% [markdown]
# ## Duplicate rows

# %%
data_product.duplicated().sum()
# Out:
# 711

# %% [markdown]
# #### There are a total of 711 duplicate rows
# - A row is flagged as a duplicate when all its values across all columns match the values of another row or rows in the DataFrame.
# - Duplicate rows are typically dropped upon discovery since they contains the same values with other rows and might cause bias.

# %%
data_product = data_product.drop_duplicates()

# %%
data_product.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Handling missing values

# %%
X = data_product.drop(columns='Revenue', axis=1)
y = data_product['Revenue']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=2)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((9788, 17), (2447, 17), (9788,), (2447,))

# %%
miscol_temp = pd.DataFrame(columns=['Columns','Num_train'])
miscol_temp_test = pd.DataFrame(columns=['Columns','Num_test'])

# %%
for col in X_train.columns:
    col_misval = X_train[col].isna().sum()
    if col_misval > 0:
        miscol_temp.loc[len(miscol_temp)] = [col, col_misval]
        
for col in X_test.columns:
    col_misval = X_test[col].isna().sum()
    if col_misval > 0:
        miscol_temp_test.loc[len(miscol_temp_test)] = [col, col_misval]

# %%
# merge the two dataset
merged_misval_df = pd.merge(miscol_temp, miscol_temp_test, on='Columns', how='inner').sort_values(by=['Num_train'], ascending=False)

merged_misval_df
# Out:
#                    Columns  Num_train  Num_test
# 2  ProductRelated_Duration        490       112
# 1  Administrative_Duration        479       115
# 4         OperatingSystems        412        95
# 0           Administrative         82        24
# 3              BounceRates         54        15

# %% [markdown]
# #### There are a total of 5 columns with missing value
# - Administrative
# - Administrative_Duration
# - ProductRelated_Duration
# - BounceRates
# - OperatingSystems

# %%
# the missing values in columns 'Administrative','Administrative_Duration','ProductRelated_Duration' is replaced by 0.
# the assumptions is visitor did not visit administrative page, thus result in 0 seconds spent on the page.
# and the visitor did not spent time browsing through product related page thus result in 0 seconds spent on the page.
for col in ['Administrative','Administrative_Duration','ProductRelated_Duration']:
    X_train[col] = X_train[col].fillna(0)
    X_test[col] = X_test[col].fillna(0)

# %%
# the column BounceRates is replaced by it's average values
# this is done because the mean and std doesn't have much difference in values.
# which could also mean lack of outliers
X_train['BounceRates'] = X_train['BounceRates'].fillna(X_train['BounceRates'].mean())
X_test['BounceRates'] = X_test['BounceRates'].fillna(X_test['BounceRates'].mean())

# the column OperatingSystems is replaced by it's most frequent value
X_train['OperatingSystems'] = X_train['OperatingSystems'].fillna(X_train['OperatingSystems'].mode().loc[0])
X_test['OperatingSystems'] = X_test['OperatingSystems'].fillna(X_test['OperatingSystems'].mode().loc[0])

# %%
X_train.isna().sum()
# Out:
# Administrative             0
# Administrative_Duration    0
# Informational              0
# Informational_Duration     0
# ProductRelated             0
# ProductRelated_Duration    0
# BounceRates                0
# ExitRates                  0
# PageValues                 0
# SpecialDay                 0
# Month                      0
# OperatingSystems           0
# Browser                    0
# Region                     0
# TrafficType                0
# VisitorType                0
# Weekend                    0
# dtype: int64

# %%
X_test.isna().sum()
# Out:
# Administrative             0
# Administrative_Duration    0
# Informational              0
# Informational_Duration     0
# ProductRelated             0
# ProductRelated_Duration    0
# BounceRates                0
# ExitRates                  0
# PageValues                 0
# SpecialDay                 0
# Month                      0
# OperatingSystems           0
# Browser                    0
# Region                     0
# TrafficType                0
# VisitorType                0
# Weekend                    0
# dtype: int64

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((9788, 17), (2447, 17), (9788,), (2447,))

# %% [markdown]
# ## Handling Outliers

# %%
df_outlier_train = pd.DataFrame(columns=['Features','Train_upper_outlier'])
df_outlier_test = pd.DataFrame(columns=['Features','Test_upper_outlier'])

# %%
def outlier_values(df, df_output):
    for col in X_train:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        outlier = (Q3 + 1.5 * IQR)
        if outlier > 0:
            df_output.loc[len(df_output)] = [col, outlier.round(2)]

# %%
outlier_values(X_train, df_outlier_train)
df_outlier_train
# Out:
#                    Features  Train_upper_outlier
# 0            Administrative                10.00
# 1   Administrative_Duration               221.50
# 2            ProductRelated                84.50
# 3   ProductRelated_Duration              3291.30
# 4               BounceRates                 0.04
# 5                 ExitRates                 0.10
# 6                     Month                10.00
# 7          OperatingSystems                 2.00
# 8                   Browser                 2.00
# 9                    Region                 8.50
# 10              TrafficType                 7.00
# 11              VisitorType                 2.00

# %%
outlier_values(X_test, df_outlier_test)
df_outlier_test
# Out:
#                    Features  Test_upper_outlier
# 0            Administrative               10.00
# 1   Administrative_Duration              220.00
# 2            ProductRelated               83.00
# 3   ProductRelated_Duration             3445.17
# 4               BounceRates                0.04
# 5                 ExitRates                0.10
# 6                     Month               11.50
# 7          OperatingSystems                2.00
# 8                   Browser                2.00
# 9                    Region                8.50
# 10              TrafficType                7.00
# 11              VisitorType                2.00

# %%
# merge the two dataset
merged_outlier_df = pd.merge(df_outlier_train, df_outlier_test, on='Features', how='inner').sort_values(by=['Train_upper_outlier'], ascending=False)

merged_outlier_df
# Out:
#                    Features  Train_upper_outlier  Test_upper_outlier
# 3   ProductRelated_Duration              3291.30             3445.17
# 1   Administrative_Duration               221.50              220.00
# 2            ProductRelated                84.50               83.00
# 0            Administrative                10.00               10.00
# 6                     Month                10.00               11.50
# 9                    Region                 8.50                8.50
# 10              TrafficType                 7.00                7.00
# 7          OperatingSystems                 2.00                2.00
# 8                   Browser                 2.00                2.00
# 11              VisitorType                 2.00                2.00
# 5                 ExitRates                 0.10                0.10
# 4               BounceRates                 0.04                0.04

# %%
df_perc_temp = pd.DataFrame(columns=['Features','Train_outlier_percentages','Test_outlier_percentages'])

# %%
for index, row in merged_outlier_df.iterrows():
    train_outlier_val = row['Train_upper_outlier']
    test_outlier_val = row['Test_upper_outlier']
    
    train_outlier_count = X_train[row['Features']] > train_outlier_val
    test_outlier_count = X_test[row['Features']] > test_outlier_val
    
    train_outlier_percentage = round(train_outlier_count.sum()/len(X_train)*100,2)
    test_outlier_percentage = round(test_outlier_count.sum()/len(X_test)*100,2)
    
    df_perc_temp.loc[len(df_perc_temp)] = [row['Features'], train_outlier_percentage, test_outlier_percentage]

# %%
df_perc_temp.sort_values('Train_outlier_percentages', ascending=False)
# Out:
#                    Features  Train_outlier_percentages  \
# 7          OperatingSystems                      24.38
# 6               TrafficType                      17.08
# 8                   Browser                      15.53
# 11              BounceRates                      11.90
# 1   Administrative_Duration                       9.78
# 10                ExitRates                       8.28
# 2            ProductRelated                       7.89
# 0   ProductRelated_Duration                       7.75
# 5                    Region                       4.09
# 3            Administrative                       3.16
# 4                     Month                       0.00
# 9               VisitorType                       0.00
#
#     Test_outlier_percentages
# 7                      24.52
# 6                      17.00
# 8                      15.37
# 11                     12.38
# 1                      10.22
# 10                      8.46
# 2                       8.95
# 0                       7.48
# 5                       4.29
# 3                       3.72
# 4                       0.00
# 9                       0.00

# %% [markdown]
# #### Notes:
# - There are 10 features containing outliers, 2 of which (Month, VisitorType) have close to zero values beyond their upper outlier threshold.
# - There are 3 features with the highest percentages of outliers, which are "TrafficType," "BounceRates," and "Administrative_Duration," with more than 10% of their values as outliers. This indicates that a significant number of data points fall outside the expected range of the majority of the data in a column. This would suggests that the central tendency (mean, median) of the features is highly distorted.
# - According to National Institute of Standards and Technology, any values that exceed the upper inner fence of outliers (Q3 + 1.5*IQR) are considered to be mild outliers.

# %%
transform_train = X_train.skew() > 1

# Do log transformation
X_train.loc[:, transform_train] = X_train.loc[:, transform_train].apply(lambda x: np.log1p(x))

# Apply the same transformation to the testing set (to maintain consistency)
X_test.loc[:, transform_train] = X_test.loc[:, transform_train].apply(lambda x: np.log1p(x))

# Display the transformed DataFrames
X_train.describe().T
# Out:
#                           count      mean       std       min       25%  \
# Administrative           9788.0  0.798990  0.860840  0.000000  0.000000
# Administrative_Duration  9788.0  2.226090  2.359143  0.000000  0.000000
# Informational            9788.0  0.239039  0.494848  0.000000  0.000000
# Informational_Duration   9788.0  0.856666  1.826609  0.000000  0.000000
# ProductRelated           9788.0  2.896130  1.111301  0.000000  2.079442
# ProductRelated_Duration  9788.0  5.709474  2.328519  0.000000  4.989014
# BounceRates              9788.0  0.019508  0.042017  0.000000  0.000000
# ExitRates                9788.0  0.039996  0.042896  0.000000  0.014159
# PageValues               9788.0  0.629828  1.275214  0.000000  0.000000
# SpecialDay               9788.0  0.046824  0.148067  0.000000  0.000000
# Month                    9788.0  5.164078  2.368618  0.000000  5.000000
# OperatingSystems         9788.0  1.102053  0.260204  0.693147  1.098612
# Browser                  9788.0  1.132809  0.359803  0.693147  1.098612
# Region                   9788.0  3.139865  2.397027  1.000000  1.000000
# TrafficType              9788.0  1.406060  0.613497  0.693147  1.098612
# VisitorType              9788.0  1.711892  0.697507  0.000000  2.000000
# Weekend                  9788.0  0.163160  0.294078  0.000000  0.000000
#
#                               50%       75%        max
# Administrative           0.693147  1.609438   3.295837
# Administrative_Duration  1.386294  4.495367   8.131457
# Informational            0.000000  0.000000   3.218876
# Informational_Duration   0.000000  0.000000   7.843996
# ProductRelated           2.944439  3.663562   6.559615
# ProductRelated_Duration  6.314152  7.247790  11.066240
# BounceRates              0.003003  0.016529   0.182322
# ExitRates                0.024693  0.047445   0.182322
# PageValues               0.000000  0.000000   5.893752
# SpecialDay               0.000000  0.000000   0.693147
# Month                    6.000000  7.000000   9.000000
# OperatingSystems         1.098612  1.098612   2.197225
# Browser                  1.098612  1.098612   2.639057
# Region                   3.000000  4.000000   9.000000
# TrafficType              1.098612  1.609438   3.044522
# VisitorType              2.000000  2.000000   2.000000
# Weekend                  0.000000  0.000000   0.693147

# %%
X_test.describe().T
# Out:
#                           count      mean       std       min       25%  \
# Administrative           2447.0  0.781555  0.869289  0.000000  0.000000
# Administrative_Duration  2447.0  2.182953  2.371672  0.000000  0.000000
# Informational            2447.0  0.237539  0.505695  0.000000  0.000000
# Informational_Duration   2447.0  0.827771  1.803138  0.000000  0.000000
# ProductRelated           2447.0  2.927402  1.113592  0.000000  2.197225
# ProductRelated_Duration  2447.0  5.742624  2.337354  0.000000  5.041799
# BounceRates              2447.0  0.020112  0.042429  0.000000  0.000000
# ExitRates                2447.0  0.040288  0.042813  0.000000  0.014185
# PageValues               2447.0  0.625545  1.256954  0.000000  0.000000
# SpecialDay               2447.0  0.048248  0.150183  0.000000  0.000000
# Month                    2447.0  5.180221  2.390832  0.000000  4.000000
# OperatingSystems         2447.0  1.102338  0.260451  0.693147  1.098612
# Browser                  2447.0  1.127406  0.361966  0.693147  1.098612
# Region                   2447.0  3.199428  2.420838  1.000000  1.000000
# TrafficType              2447.0  1.399192  0.611746  0.693147  1.098612
# VisitorType              2447.0  1.735595  0.673020  0.000000  2.000000
# Weekend                  2447.0  0.158345  0.291063  0.000000  0.000000
#
#                               50%       75%        max
# Administrative           0.693147  1.609438   3.332205
# Administrative_Duration  0.000000  4.488636   7.786728
# Informational            0.000000  0.000000   2.564949
# Informational_Duration   0.000000  0.000000   7.333676
# ProductRelated           2.995732  3.663562   6.532334
# ProductRelated_Duration  6.344056  7.293913  10.120418
# BounceRates              0.003472  0.017493   0.182322
# ExitRates                0.025201  0.048790   0.182322
# PageValues               0.000000  0.000000   5.605010
# SpecialDay               0.000000  0.000000   0.693147
# Month                    6.000000  7.000000   9.000000
# OperatingSystems         1.098612  1.098612   2.197225
# Browser                  1.098612  1.098612   2.639057
# Region                   3.000000  4.000000   9.000000
# TrafficType              1.098612  1.609438   3.044522
# VisitorType              2.000000  2.000000   2.000000
# Weekend                  0.000000  0.000000   0.693147

# %%
transformed_outlier_train = pd.DataFrame(columns=['Features','Train_upper_outlier'])
transformed_outlier_test = pd.DataFrame(columns=['Features','Test_upper_outlier'])

# %%
outlier_values(X_train, transformed_outlier_train)
outlier_values(X_test, transformed_outlier_test)

# %%
# merge the two dataset
merged_outlier_transformed = pd.merge(transformed_outlier_train, transformed_outlier_test, on='Features', how='inner').sort_values(by=['Train_upper_outlier'], ascending=False)

merged_outlier_transformed
# Out:
#                    Features  Train_upper_outlier  Test_upper_outlier
# 1   Administrative_Duration                11.24               11.22
# 3   ProductRelated_Duration                10.64               10.67
# 6                     Month                10.00               11.50
# 9                    Region                 8.50                8.50
# 2            ProductRelated                 6.04                5.86
# 0            Administrative                 4.02                4.02
# 10              TrafficType                 2.38                2.38
# 11              VisitorType                 2.00                2.00
# 7          OperatingSystems                 1.10                1.10
# 8                   Browser                 1.10                1.10
# 5                 ExitRates                 0.10                0.10
# 4               BounceRates                 0.04                0.04

# %%
perc_outlier_transformed = pd.DataFrame(columns=['Features','Train_outlier_percentages','Test_outlier_percentages'])

# %%
for index, row in merged_outlier_transformed.iterrows():
    train_outlier_val = row['Train_upper_outlier']
    test_outlier_val = row['Test_upper_outlier']
    
    train_outlier_count = X_train[row['Features']] > train_outlier_val
    test_outlier_count = X_test[row['Features']] > test_outlier_val
    
    train_outlier_percentage = round(train_outlier_count.sum()/len(X_train)*100,2)
    test_outlier_percentage = round(test_outlier_count.sum()/len(X_test)*100,2)

    if train_outlier_percentage > 0 and test_outlier_percentage > 0:
        perc_outlier_transformed.loc[len(perc_outlier_transformed)] = [row['Features'], train_outlier_percentage, test_outlier_percentage]

# %%
perc_outlier_transformed.sort_values('Train_outlier_percentages', ascending=False)
# Out:
#            Features  Train_outlier_percentages  Test_outlier_percentages
# 3  OperatingSystems                      24.38                     24.52
# 4           Browser                      15.53                     15.37
# 2       TrafficType                      13.93                     13.94
# 6       BounceRates                      11.87                     12.38
# 5         ExitRates                       8.13                      8.26
# 0            Region                       4.09                      4.29
# 1    ProductRelated                       0.10                      0.33

# %% [markdown]
# #### Notes:
# - Out of 10 features, There are only 5 features left with the presence of outliers, with 4 features (TrafficType, BounceRates, ExitRates, Region) is still has a fairly high percentages of outliers, and 1 feature (ProductRelated) is close to zero percent.
# - Logarithmic transformation manages to reduce 5 out of 10 features to very close to zero percent, which are promptly excluded.

# %%
from scipy.stats.mstats import winsorize

for col in perc_outlier_transformed['Features']:
    X_train[col] = winsorize(X_train[col], limits=[0.15, 0.15])
    X_test[col] = winsorize(X_test[col], limits=[0.15, 0.15])

# %%
perc_outlier_transformed = pd.DataFrame(columns=['Features','Train_outlier_percentages','Test_outlier_percentages'])

# %%
for index, row in merged_outlier_transformed.iterrows():
    train_outlier_val = row['Train_upper_outlier']
    test_outlier_val = row['Test_upper_outlier']
    
    train_outlier_count = X_train[row['Features']] > train_outlier_val
    test_outlier_count = X_test[row['Features']] > test_outlier_val
    
    train_outlier_percentage = round(train_outlier_count.sum()/len(X_train)*100,2)
    test_outlier_percentage = round(test_outlier_count.sum()/len(X_test)*100,2)

    if train_outlier_percentage > 0 and test_outlier_percentage > 0:
        perc_outlier_transformed.loc[len(perc_outlier_transformed)] = [row['Features'], train_outlier_percentage, test_outlier_percentage]

# %%
perc_outlier_transformed.sort_values('Train_outlier_percentages', ascending=False)
# Out:
#            Features  Train_outlier_percentages  Test_outlier_percentages
# 0  OperatingSystems                      24.38                     24.52
# 1           Browser                      15.53                     15.37

# %% [markdown]
# #### Notes:
# - There are 2 features left that have outliers after using winsorization.
# - By applying winsorization with the 15th and 85th percentile limits, this means that any values below the 15th percentile will be replaced with the value at the 15th percentile, and any values above the 85th percentile will be replaced with the value at the 85th percentile

# %% [markdown]
# ## SMOTE
# - Oversampling technique that helps to improve the performance of machine learning models by balancing the class distribution, particularly useful when the minority class is underrepresented.
# - SMOTE works by creating synthetic examples from the minority class by interpolating between existing minority class instances.

# %%
from imblearn.over_sampling import SMOTE
#handle imbalance target using SMOTE
smt = SMOTE(random_state =2)
smt.fit(X_train, y_train)
X_smote, y_smote = smt.fit_resample(X_train, y_train)

#display row and column for data smote & data test
X_smote.shape, X_train.shape, y_smote.shape, y_test.shape
# Out:
# ((16524, 17), (9788, 17), (16524,), (2447,))

# %% [markdown]
# # Features Engineering

# %% [markdown]
# ### Numerical Column Selection
# Column selection criteria for numerical data:
# - No null values
# - p-value < 0.05
# - correlation coefficient <= 0.7

# %%
# Create new dataframe without column with dtypes 'object'
x_train_num = X_smote.select_dtypes(exclude='object')
x_train_num.columns
# Out:
# Index(['Administrative', 'Administrative_Duration', 'Informational',
#        'Informational_Duration', 'ProductRelated', 'ProductRelated_Duration',
#        'BounceRates', 'ExitRates', 'PageValues', 'SpecialDay', 'Month',
#        'OperatingSystems', 'Browser', 'Region', 'TrafficType', 'VisitorType',
#        'Weekend'],
#       dtype='object')

# %%
x_train_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16524 entries, 0 to 16523
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Administrative           16524 non-null  float64
#  1   Administrative_Duration  16524 non-null  float64
#  2   Informational            16524 non-null  float64
#  3   Informational_Duration   16524 non-null  float64
#  4   ProductRelated           16524 non-null  float64
#  5   ProductRelated_Duration  16524 non-null  float64
#  6   BounceRates              16524 non-null  float64
#  7   ExitRates                16524 non-null  float64
#  8   PageValues               16524 non-null  float64
#  9   SpecialDay               16524 non-null  float64
#  10  Month                    16524 non-null  int32
#  11  OperatingSystems         16524 non-null  float64
#  12  Browser                  16524 non-null  float64
#  13  Region                   16524 non-null  int64
#  14  TrafficType              16524 non-null  float64
#  15  VisitorType              16524 non-null  int32
#  16  Weekend                  16524 non-null  float64
# dtypes: float64(14), int32(2), int64(1)
# memory usage: 2.0 MB

# %%
from sklearn.feature_selection import f_classif

# Use ANOVA to get the p-value
F_statistic, p_values = f_classif(x_train_num, y_smote)

#create dataframe 
df_anova = pd.DataFrame(data= {'Numerical Feature':x_train_num.columns.values,
                                'p-value': p_values.round(5)})

df_anova.shape
# Out:
# (17, 2)

# %%
df_anova
# Out:
#           Numerical Feature  p-value
# 0            Administrative  0.00000
# 1   Administrative_Duration  0.00000
# 2             Informational  0.00000
# 3    Informational_Duration  0.00000
# 4            ProductRelated  0.00000
# 5   ProductRelated_Duration  0.00000
# 6               BounceRates  0.00000
# 7                 ExitRates  0.00000
# 8                PageValues  0.00000
# 9                SpecialDay  0.00000
# 10                    Month  0.00000
# 11         OperatingSystems  0.00000
# 12                  Browser  0.00017
# 13                   Region  0.00000
# 14              TrafficType  0.24560
# 15              VisitorType  0.00000
# 16                  Weekend  0.00006

# %%
#filter only column that has p-value < 0.05
temp_num_cols = df_anova[df_anova['p-value']<0.05]['Numerical Feature'].tolist()

print(f'Number of excluded columns: {len(df_anova)-len(temp_num_cols)}')

temp_num_cols
# Out:
# Number of excluded columns: 1
# ['Administrative',
#  'Administrative_Duration',
#  'Informational',
#  'Informational_Duration',
#  'ProductRelated',
#  'ProductRelated_Duration',
#  'BounceRates',
#  'ExitRates',
#  'PageValues',
#  'SpecialDay',
#  'Month',
#  'OperatingSystems',
#  'Browser',
#  'Region',
#  'VisitorType',
#  'Weekend']

# %% [markdown]
# - 1 features (TrafficType) are dropped because their p-value is more than the 0.05 threshold criterion.

# %%
#select only the columns with correlation < 0.7
corr = X_smote[temp_num_cols].corr()
fig = plt.figure(figsize=(20,20))

# create heatmap to show correlation between features
sns.heatmap(corr, annot=True, mask=(abs(corr)<=0.7))
# Out:
# <Axes: >

# %%
#create and apply mask
mask = corr.where(np.triu(np.ones(corr.shape, dtype = bool), k=1))

# %%
corr_selected_col = [col for col in mask.columns if any (mask[col] < 0.7)]

print(f'Number of excluded columns: {len(temp_num_cols)-len(corr_selected_col)}')

corr_selected_col
# Out:
# Number of excluded columns: 2
# ['Informational',
#  'Informational_Duration',
#  'ProductRelated',
#  'ProductRelated_Duration',
#  'BounceRates',
#  'ExitRates',
#  'PageValues',
#  'SpecialDay',
#  'Month',
#  'OperatingSystems',
#  'Browser',
#  'Region',
#  'VisitorType',
#  'Weekend']

# %% [markdown]
# - 2 features (Administrative, Administrative_Duration) are dropped because their correlation value is less than the 0.7 threshold criterion.

# %%
X_train_final = X_smote[corr_selected_col]
X_test_final = X_test[corr_selected_col]

# %%
X_train_final.shape, X_test_final.shape
# Out:
# ((16524, 14), (2447, 14))

# %%
X_train_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16524 entries, 0 to 16523
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Informational            16524 non-null  float64
#  1   Informational_Duration   16524 non-null  float64
#  2   ProductRelated           16524 non-null  float64
#  3   ProductRelated_Duration  16524 non-null  float64
#  4   BounceRates              16524 non-null  float64
#  5   ExitRates                16524 non-null  float64
#  6   PageValues               16524 non-null  float64
#  7   SpecialDay               16524 non-null  float64
#  8   Month                    16524 non-null  int32
#  9   OperatingSystems         16524 non-null  float64
#  10  Browser                  16524 non-null  float64
#  11  Region                   16524 non-null  int64
#  12  VisitorType              16524 non-null  int32
#  13  Weekend                  16524 non-null  float64
# dtypes: float64(11), int32(2), int64(1)
# memory usage: 1.6 MB

# %% [markdown]
# ## Drop unnecessary columns

# %%
# Visitor operating system and browser are judged to be irrelevant with the target feature.
unn_col = ['OperatingSystems', 'Browser']
for col in unn_col:
    X_train_final.drop(columns=col, axis=1, inplace=True)
    X_test_final.drop(columns=col, axis=1, inplace=True)

# %% [markdown]
# #### Notes:
# - Column 'OperatingSystems' described as the operating system used by the visitor.
# - Column 'Browser' described as the web browser used by the visitor

# %% [markdown]
# ## Features Extraction

# %%
X_test_final.shape
# Out:
# (2447, 12)

# %%
def specialD(df):
    for index, row in df.iterrows():
        if row['SpecialDay'] <=0.2:
            df.at[index, 'SpecialD_Category'] = 'Close'
        elif row['SpecialDay'] <=0.4:
            df.at[index, 'SpecialD_Category'] = 'Moderate'
        elif row['SpecialDay'] <=1:
            df.at[index, 'SpecialD_Category'] = 'Far'
            
    df['SpecialD_Category'] = label_encoder.fit_transform(df['SpecialD_Category'])

specialD(X_train_final)
specialD(X_test_final)

# %%
X_train_final = X_train_final.drop(columns='SpecialDay', axis=1)
X_test_final = X_test_final.drop(columns='SpecialDay', axis=1)

# %%
X_train_final['Bounces_to_exit_ratio'] = X_train_final['BounceRates']/X_train_final['ExitRates']
X_test_final['Bounces_to_exit_ratio'] = X_train_final['BounceRates']/X_train_final['ExitRates']

# %%
extracted_col = ['BounceRates', 'ExitRates']
for col in extracted_col:
    X_train_final.drop(columns=col, axis=1, inplace=True)
    X_test_final.drop(columns=col, axis=1, inplace=True)

# %%
X_train_final['Bounces_to_exit_ratio'].describe()
# Out:
# count    16524.000000
# mean         0.217717
# std          0.251399
# min          0.000000
# 25%          0.000000
# 50%          0.140275
# 75%          0.416389
# max          2.479011
# Name: Bounces_to_exit_ratio, dtype: float64

# %%
X_train_final.shape, X_test_final.shape
# Out:
# ((16524, 11), (2447, 11))

# %%
X_train_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16524 entries, 0 to 16523
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Informational            16524 non-null  float64
#  1   Informational_Duration   16524 non-null  float64
#  2   ProductRelated           16524 non-null  float64
#  3   ProductRelated_Duration  16524 non-null  float64
#  4   PageValues               16524 non-null  float64
#  5   Month                    16524 non-null  int32
#  6   Region                   16524 non-null  int64
#  7   VisitorType              16524 non-null  int32
#  8   Weekend                  16524 non-null  float64
#  9   SpecialD_Category        16524 non-null  int32
#  10  Bounces_to_exit_ratio    16524 non-null  float64
# dtypes: float64(7), int32(3), int64(1)
# memory usage: 1.2 MB

# %%
X_test_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2447 entries, 5994 to 983
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Informational            2447 non-null   float64
#  1   Informational_Duration   2447 non-null   float64
#  2   ProductRelated           2447 non-null   float64
#  3   ProductRelated_Duration  2447 non-null   float64
#  4   PageValues               2447 non-null   float64
#  5   Month                    2447 non-null   int32
#  6   Region                   2447 non-null   int64
#  7   VisitorType              2447 non-null   int32
#  8   Weekend                  2447 non-null   float64
#  9   SpecialD_Category        2447 non-null   int32
#  10  Bounces_to_exit_ratio    2447 non-null   float64
# dtypes: float64(7), int32(3), int64(1)
# memory usage: 265.3 KB

# %% [markdown]
# # Modelling

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBRegressor
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, roc_auc_score, roc_curve, auc, confusion_matrix

def class_report(y_proba, y):
    y_pred_class = []

    for val in y_proba:
        if val > 0.5:
            y_pred_class.append(1)
        else:
            y_pred_class.append(0)
    
    print(classification_report(y_true = y, y_pred= y_pred_class))
    conf_matrix(y, y_pred_class)

def conf_matrix(y, y_pred):
    conf_matrix = confusion_matrix(y_true=y, y_pred=y_pred)

    print(f"Test data Confusion Matrix:")
    print(conf_matrix,'\n')
    
ml_model = {'Logistic Regression':LogisticRegression(),
            'K-Nearest Neighbor':KNeighborsClassifier(),
            'Decision Tree':DecisionTreeClassifier(),
            'Random Forest':RandomForestClassifier(),
            'XGB':XGBRegressor()}

for model_name, model_used in ml_model.items():
    model_used.fit(X_train_final, y_smote)
    if model_name != 'XGB':
        y_pred_proba_train = model_used.predict_proba(X_train_final)[:][:,1]
        y_pred_proba_test = model_used.predict_proba(X_test_final)[:][:,1]
    else:
        y_pred_proba_train = model_used.predict(X_train_final)
        y_pred_proba_test = model_used.predict(X_test_final)
        
    print(f'{model_name} AUC train probability: ', roc_auc_score(y_true= y_smote , y_score= y_pred_proba_train).round(4))
    print(f'{model_name} AUC test probability: ', roc_auc_score(y_true= y_test , y_score= y_pred_proba_test).round(4))

    class_report(y_pred_proba_test, y_test)
# Out:
# Logistic Regression AUC train probability:  0.9051
# Logistic Regression AUC test probability:  0.9023
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.92      2065
#            1       0.58      0.80      0.67       382
#
#     accuracy                           0.88      2447
#    macro avg       0.77      0.85      0.80      2447
# weighted avg       0.90      0.88      0.89      2447
#
# Test data Confusion Matrix:
# [[1842  223]
#  [  76  306]]
#
# K-Nearest Neighbor AUC train probability:  0.9861
# K-Nearest Neighbor AUC test probability:  0.8629
#               precision    recall  f1-score   support
#
#            0       0.96      0.83      0.89      2065
#            1       0.47      0.79      0.59       382
#
#     accuracy                           0.83      2447
#    macro avg       0.71      0.81      0.74      2447
# weighted avg       0.88      0.83      0.84      2447
#
# Test data Confusion Matrix:
# [[1718  347]
#  [  80  302]]
#
# Decision Tree AUC train probability:  1.0
# Decision Tree AUC test probability:  0.7426
#               precision    recall  f1-score   support
#
#            0       0.92      0.87      0.90      2065
#            1       0.46      0.62      0.53       382
#
#     accuracy                           0.83      2447
#    macro avg       0.69      0.74      0.71      2447
# weighted avg       0.85      0.83      0.84      2447
#
# Test data Confusion Matrix:
# [[1794  271]
#  [ 147  235]]
#
# Random Forest AUC train probability:  0.9999
# Random Forest AUC test probability:  0.9001
#               precision    recall  f1-score   support
#
#            0       0.95      0.90      0.92      2065
#            1       0.58      0.74      0.65       382
#
#     accuracy                           0.88      2447
#    macro avg       0.76      0.82      0.79      2447
# weighted avg       0.89      0.88      0.88      2447
#
# Test data Confusion Matrix:
# [[1860  205]
#  [ 100  282]]
#
# XGB AUC train probability:  0.9955
# XGB AUC test probability:  0.8946
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92      2065
#            1       0.58      0.71      0.64       382
#
#     accuracy                           0.87      2447
#    macro avg       0.76      0.81      0.78      2447
# weighted avg       0.89      0.87      0.88      2447
#
# Test data Confusion Matrix:
# [[1868  197]
#  [ 112  270]]

# %% [markdown]
# #### Notes:
# #### AUC
# - AUC (Area Under Curve) according to (Narkhede, 2018) is a performance measurement or metric used to evaluate the performance of classification models.
# - Higher AUC value indicates better class separation, as the model is able to distinguish between the positive and negative classes more effectively.
# - AUC > 0.8: Generally is considered a good performance.
# - AUC > 0.9: Is considered a very good performance.
# - AUC < 0.5: Indicates the model performs no better than random.
#
# #### Confusion matrix
# To maximize revenue using the prediction results, it's generally better to consider both true positives (visitors correctly predicted to generate revenue) and false negatives (visitors incorrectly predicted to not generate revenue). This would helps in avoiding potential losses on paying customers while also potentially converting non-paying customer to paying customer.

# %% [markdown]
# #### Insight:
# - On average, the five models can identify visitors who will generate revenue (1) with only 53.2% precision. The top performing models, Logistic Regression, Random Forest, and XGBoost, achieve slightly better prevision at around 58%. However, these models excel at identifying visitors who will not generate revenue (0), with an average precision of 94.6%.
# - All models except the decision tree can be considered to have a good recall score (greater than 0.70) for visitors who generate revenue. This indicates that the models were able to identify a good portion of visitors who actually generate revenue for the site.
# - The top performing models, Logistic Regression, Random Forest, and XGBoost manages to have a fairly moderate f1-score on class (1) which indicates the harmonized score between precision and recall of the models manages to correctly identifies a good portion visitor that would generate revenue.
# - Across all models, the accuracy scores are good and consistent, with an average of 85.8%. This suggests that the models are generally effective at making accurate predictions, although the top performers excel even further in this area with each are well above the total average.
# - 0.9 AUC score from the top performing models on both train & test probability suggest that the models performance considered to be very good, and is effective at distinguishing between the positive and negative classes.
# - The true positive to false negative ratio indicates that, on average, the models can identify paying customers (TP) 18.6 times more often than they miss them (FN). This suggests a strong ability to capture potential revenue.

# %% [markdown]
# ## Hypertuning

# %% [markdown]
# Based on the evaluation results of five different classification models, considering the scores for precision, recall, and accuracy, it has been determined that the following models are the three top-performing models that will be hypertuned:
# - Logistic Regression
# - Random Forest
# - XGBoost

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.model_selection import GridSearchCV

#Membuat dictionary jarak nilai parameter C
param_grid = {
    'penalty': ['l1', 'l2'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'solver': ['liblinear', 'newton-cg', 'saga'],
    'class_weight': [None, 'balanced']
}

#Membuat LogisticRegression
model = LogisticRegression()

#Melakukan gridsearch
grid_search = GridSearchCV(model, param_grid, cv=5)
grid_search.fit(X_train_final, y_smote)

#Assign value terbaik C
#best_C = grid_search.best_params_['C']
best_params = grid_search.best_params_

#Membuat model baru dengan param C
best_model = LogisticRegression(**best_params)

print(f'Parameters used: {best_params}')
# Out:
# Parameters used: {'C': 0.01, 'class_weight': None, 'penalty': 'l1', 'solver': 'saga'}

# %%
#Latih model
best_model.fit(X_train_final, y_smote)

y_pred_proba_train_hyp = best_model.predict_proba(X_train_final)[:][:,1]
y_pred_proba_test_hyp = best_model.predict_proba(X_test_final)[:][:,1]

#AUC - ROC curve is a performance measurement for the classification problems at various threshold settings
print('AUC train probability: ', roc_auc_score(y_true= y_smote , y_score= y_pred_proba_train_hyp))
print('AUC test probability: ', roc_auc_score(y_true= y_test , y_score= y_pred_proba_test_hyp))
# Out:
# AUC train probability:  0.9037561013927732
# AUC test probability:  0.8989928121394977

# %%
y_pred_class_hyp_logreg = []

for val in y_pred_proba_test_hyp:
    if val > 0.5:
        y_pred_class_hyp_logreg.append(1)
    else:
        y_pred_class_hyp_logreg.append(0)

print(classification_report(y_true = y_test, y_pred= y_pred_class_hyp_logreg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93      2065
#            1       0.59      0.80      0.68       382
#
#     accuracy                           0.88      2447
#    macro avg       0.77      0.85      0.80      2447
# weighted avg       0.90      0.88      0.89      2447

# %%
conf_matrix(y_test, y_pred_class_hyp_logreg)
# Out:
# Test data Confusion Matrix:
# [[1850  215]
#  [  77  305]]

# %% [markdown]
# #### Insight:
# - Hypertuning Logistic Regression model with the best parameter possible resulted in increase of precision and f1-score for class (1) by 0.01 which is not significant.
# - Confusion matrix shows little to no increase.

# %% [markdown]
# ### Random Forest

# %%
# Create a Random Forest model
random_f = RandomForestClassifier(max_features= 'log2', min_samples_leaf= 2, min_samples_split= 0.1, n_estimators= 500, verbose=True, criterion='entropy')

random_f.fit(X_train_final, y_smote)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:    4.7s finished
# RandomForestClassifier(criterion='entropy', max_features='log2',
#                        min_samples_leaf=2, min_samples_split=0.1,
#                        n_estimators=500, verbose=True)

# %%
y_pred_proba_train_hyp = random_f.predict_proba(X_train_final)[:][:,1]
y_pred_proba_test_hyp = random_f.predict_proba(X_test_final)[:][:,1]

#AUC - ROC curve is a performance measurement for the classification problems at various threshold settings
print('AUC train probability: ', roc_auc_score(y_true= y_smote , y_score= y_pred_proba_train_hyp))
print('AUC test probability: ', roc_auc_score(y_true= y_test , y_score= y_pred_proba_test_hyp))
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# AUC train probability:  0.9368161835683825
# AUC test probability:  0.9040870656541967
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 500 out of 500 | elapsed:    0.0s finished

# %%
y_pred_class_hyp_rf = []

for val in y_pred_proba_test_hyp:
    if val > 0.5:
        y_pred_class_hyp_rf.append(1)
    else:
        y_pred_class_hyp_rf.append(0)

print(classification_report(y_true = y_test, y_pred= y_pred_class_hyp_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.92      2065
#            1       0.57      0.81      0.67       382
#
#     accuracy                           0.88      2447
#    macro avg       0.77      0.85      0.80      2447
# weighted avg       0.90      0.88      0.88      2447

# %%
conf_matrix(y_test, y_pred_class_hyp_rf)
# Out:
# Test data Confusion Matrix:
# [[1831  234]
#  [  71  311]]

# %% [markdown]
# #### Insight:
# - Hypertuning the Random Forest model with the selected parameters led to an increase in the class (1) recall and f1-score values by 0.7 and 0.2, respectively.
# - The confusion matrix indicates that the model performs better at predicting visitors who didn't generate revenue, although its ability to predict visitors who actually generate revenue has slightly decreased. While the increase in false positives may lead to some inefficiencies, they still represent potential revenue opportunities. False negatives, on the other hand, represent missed revenue opportunities and can have a more significant impact on overall revenue and would be better to be kept at lower number.

# %%
XGB_model_hyp = XGBRegressor(n_estimators=100, learning_rate=0.3, max_depth=9)

# Train the model
XGB_model_hyp.fit(X_train_final, y_smote)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.3, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=9, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
y_pred_proba_train_hyp = model_used.predict(X_train_final)
y_pred_proba_test_hyp = model_used.predict(X_test_final)

print(f'{model_name} AUC train probability: ', roc_auc_score(y_true= y_smote , y_score= y_pred_proba_train).round(4))
print(f'{model_name} AUC test probability: ', roc_auc_score(y_true= y_test , y_score= y_pred_proba_test).round(4))
# Out:
# XGB AUC train probability:  0.9955
# XGB AUC test probability:  0.8946

# %%
y_pred_class_hyp_xgb = []

for val in y_pred_proba_test_hyp:
    if val > 0.5:
        y_pred_class_hyp_xgb.append(1)
    else:
        y_pred_class_hyp_xgb.append(0)

print(classification_report(y_true = y_test, y_pred= y_pred_class_hyp_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92      2065
#            1       0.58      0.71      0.64       382
#
#     accuracy                           0.87      2447
#    macro avg       0.76      0.81      0.78      2447
# weighted avg       0.89      0.87      0.88      2447

# %%
conf_matrix(y_test, y_pred_class_hyp_xgb)
# Out:
# Test data Confusion Matrix:
# [[1868  197]
#  [ 112  270]]

# %% [markdown]
# #### Insight:
# - Hypertuning the XGBoost model with the selected parameters led to an increase in the class (1) recall and f1-score values by 1 and 0.3, respectively.
# - The confusion matrix shows the same patern of changes as the random forest model, this would also indicates that the model performs better at predicting visitors who didn't generate revenue, while having slight decrease in predicting actual visitors who generate revenue.

# %% [markdown]
# ## Feature importances

# %%
feature_importances = XGB_model_hyp.feature_importances_

# %%
# Create new dataframe for top 5 feature
imp_fts = pd.DataFrame(columns=['Features','importance'])

# %%
# Get and sort feature importances with the feature names
sorted_importances = sorted(zip(X_test_final.columns, feature_importances), key=lambda x: x[1], reverse=True)

# Assign each features alongside it's importance values into the previously created dataframe
for feature, importance in sorted_importances[:5]:
    imp_fts.loc[len(imp_fts)] = [feature, importance]

# %%
print('Top 5 Feature Importances:')
imp_fts
# Out:
# Top 5 Feature Importances:
#                 Features  importance
# 0             PageValues    0.423159
# 1                Weekend    0.121146
# 2                  Month    0.118357
# 3            VisitorType    0.083263
# 4  Bounces_to_exit_ratio    0.044169

# %%
# Create barplot for top 5
ax_hbartype_gr = sns.barplot(y='Features', x='importance',data=imp_fts, palette='OrRd', orient='horizontal')

# Formatting plot
plt.bar_label(ax_hbartype_gr.containers[0], fmt='%.2f')
plt.xlabel('Importance')
plt.title('Top 5 Highest Features Importance', fontsize=15, weight ='extra bold')
# Out:
# Text(0.5, 1.0, 'Top 5 Highest Features Importance')

# %% [markdown]
# #### Insight:
# - 5 column are found with the highest importance value, which suggest that these columns are likely to be the highest determining factor in predicting visitor as potential buyer as the target features.
# - The usage of the these top 5 features as the predictor would possibly suggest better result when it comes to predicting the target feature.

# %%
# Create new dataframe for top 5 feature
bott_imp_fts = pd.DataFrame(columns=['Features','importance'])

# Get and sort feature importances with the feature names
bott_sorted_importances = sorted(zip(X_test_final.columns, feature_importances), key=lambda x: x[1], reverse=False)

# Assign each features alongside it's importance values into the previously created dataframe
for feature, importance in bott_sorted_importances[:5]:
    bott_imp_fts.loc[len(bott_imp_fts)] = [feature, importance]

# %%
# Create dataframe for the bottom 5 features
bott_imp_fts = bott_imp_fts.sort_values('importance',ascending=False)
bott_imp_fts
# Out:
#                   Features  importance
# 4                   Region    0.039780
# 3           ProductRelated    0.035149
# 2  ProductRelated_Duration    0.033984
# 1   Informational_Duration    0.030528
# 0            Informational    0.027094

# %%
# Create barplot for bottom 5
ax_imp_fts = sns.barplot(y='Features', x='importance',data=bott_imp_fts, palette='OrRd', orient='horizontal')

# Formatting plot
plt.bar_label(ax_imp_fts.containers[0], fmt='%.2f')
plt.xlabel('Importance')
plt.title('Top 5 Lowest Features Importance', fontsize=15, weight ='extra bold')
# Out:
# Text(0.5, 1.0, 'Top 5 Lowest Features Importance')

# %% [markdown]
# #### Insight:
# - 5 column are found with the lowest importance value, which suggest that these columns are likely to be the features that would matter the least and could potentially intoduce bias to the model predictions.
# - Excluding these 5 features in further analysis could lead to model prediction improvement.

# %% [markdown]
# ## Business recommendation

# %% [markdown]
# - Based on the result of analysis from the models selected, higher PageValues indicate that visitors who view more valuable pages are more likely to generate revenue. (Shankar & Kumari, 2016) suggest that providing informative content and interactive elements on a website can positively impact customer perception and ultimately the intention to purchase online.  This also suggests:
# 1. Optimizing these high-value pages or providing incentives for visitors to explore them further could lead to increased revenue.
# - Analysis on the site visitors behavior previously done reveals that visitor as potential buyer purchasing behavior can be influenced by whether their visit falls on a weekend. As noted by Shopify.com, customers are more receptive to marketing campaigns or promotions offered during weekends. This suggests that the company could:
# 1. Capitalize on this trend by focusing marketing efforts and special promotions on weekends.
# - We've found that customers tend to shop more online in the days leading up to special holidays within certain months. Based on this, the company could:
# 1. Hold back its best promotions to encourage customers to spend more at the start of these shopping weekends.
# 2. Use marketing campaigns to create a connection between these special events and specific months on the website.
# - Analysis reveals that returning visitors are more likely to generate revenue, as they are already familiar with the website and products. This suggest that there is a need to:
# 1. Create personalized offering to returning visitors
# 2. Create personalized experiences or promotions to returning visitors whcih would create brand loyalty and ultimately increase revenue.
# - We analyzed user behavior and found that most visitors who are likely to leave the site are actually returning visitors. This suggests the site is easy to use for those already familiar with it. However, new visitors are more likely to exit than browse for products. This indicates a potential problem with user experience for first-time visitors. The site might be overwhelming, requiring:
# 1. improvements in usability.
# 2. Optimizing content,
# 3. Optimizing information layout
# 4. Optimizing promotional placements which could be beneficial.
# 5. New visitors should be welcomed with clear and easy-to-understand information upon their first visit, regardless of how they arrive at the site.
